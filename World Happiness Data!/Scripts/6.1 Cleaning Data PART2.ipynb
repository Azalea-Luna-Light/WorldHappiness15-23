# %% [markdown]
# # 6.1 Cleaning Data PART2

# %% [markdown]
# ## Importing libaries

# %%
#import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## Loading Data

# %%
# Assign path variable
path = '/Users/mariamaske/World Happiness Data!/02 Data/Prepared Data'

# %%
# loading the complete dataframe
# Join path Happiness_data_complete.csv
df = pd.read_csv(os.path.join(path,'Happiness_data_complete.csv'), index_col = False)

# %% [markdown]
# ## Check for Data Consistency, Duplicates, Missings Values ...

# %%
df.shape
# Out:
# (1297, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1297 entries, 0 to 1296
# Data columns (total 16 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Unnamed: 0                                  1297 non-null   int64
#  1   Country                                     1297 non-null   object
#  2   Region                                      1297 non-null   object
#  3   Happiness Score                             1297 non-null   float64
#  4   Logged GDP per capita                       1099 non-null   float64
#  5   Healthy life expectancy                     1119 non-null   float64
#  6   Explained by: Log GDP per capita            1297 non-null   float64
#  7   Explained by: Social support                1297 non-null   float64
#  8   Explained by: Healthy life expectancy       1297 non-null   float64
# ...

# %%
df.describe()
# Out:
#         Unnamed: 0  Happiness Score  Logged GDP per capita  \
# count  1297.000000      1297.000000            1099.000000
# mean     72.040864         5.473737               9.330243
# std      42.388132         1.106996               1.182890
# min       0.000000         1.859000               5.527000
# 25%      36.000000         4.635000               8.478003
# 50%      72.000000         5.488000               9.506083
# 75%     108.000000         6.269000              10.314471
# max     155.000000         7.842000              11.758369
#
#        Healthy life expectancy  Explained by: Log GDP per capita  \
# count              1119.000000                       1297.000000
# mean                 63.867401                          1.022425
# std                   7.397826                          0.443272
# min                  38.718510                          0.000000
# 25%                  59.000000                          0.714694
# ...

# %% [markdown]
# ### Dropping not needed columns

# %% [markdown]
# ##### Since the main focus lies on the happiness rank and not on the dystopia data, I am going to drop the following columns:
# Unnamed:0 & merge column

# %%
df.drop(columns = ['Unnamed: 0','_merge', 'Key'])
# Out:
#                Country                        Region  Happiness Score  \
# 0          Switzerland                Western Europe            7.587
# 1              Iceland                Western Europe            7.561
# 2              Denmark                Western Europe            7.527
# 3               Norway                Western Europe            7.522
# 4               Canada         North America and ANZ            7.427
# ...                ...                           ...              ...
# 1292  Congo (Kinshasa)            Sub-Saharan Africa            3.207
# 1293          Zimbabwe            Sub-Saharan Africa            3.204
# 1294      Sierra Leone            Sub-Saharan Africa            3.138
# 1295           Lebanon  Middle East and North Africa            2.392
# 1296       Afghanistan                    South Asia            1.859
#
#       Logged GDP per capita  Healthy life expectancy  \
# 0                 10.857283                72.736862
# ...

# %%
# creating new subset Happiness
df_hap = df.drop(columns = ['Unnamed: 0','_merge', 'Key'])

# %%
df_hap.head()
# Out:
#        Country                 Region  Happiness Score  Logged GDP per capita  \
# 0  Switzerland         Western Europe            7.587              10.857283
# 1      Iceland         Western Europe            7.561              10.568534
# 2      Denmark         Western Europe            7.527              10.639521
# 3       Norway         Western Europe            7.522              11.048872
# 4       Canada  North America and ANZ            7.427              10.642016
#
#    Healthy life expectancy  Explained by: Log GDP per capita  \
# 0                72.736862                          1.396505
# 1                72.968559                          1.302324
# 2                70.323395                          1.325478
# 3                70.705254                          1.458997
# 4                71.443192                          1.326292
#
#    Explained by: Social support  Explained by: Healthy life expectancy  \
# ...

# %% [markdown]
# ### Changing Data types

# %% [markdown]
# ### For further analysis I will change the data type of the following collumns:
# Happiness Rank & Year

# %%
# viewing data types of df
df_hap.dtypes
# Out:
# Country                                        object
# Region                                         object
# Happiness Score                               float64
# Logged GDP per capita                         float64
# Healthy life expectancy                       float64
# Explained by: Log GDP per capita              float64
# Explained by: Social support                  float64
# Explained by: Healthy life expectancy         float64
# Explained by: Freedom to make life choices    float64
# Explained by: Generosity                      float64
# Explained by: Perceptions of corruption       float64
# Year                                            int64
# Happiness Rank                                  int64
# dtype: object

# %%
# changing year data type from integer to string
df_hap['Year'] = df_hap['Year'].astype('str')

# %%
df_hap['Year'].dtype
# Out:
# dtype('O')

# %%
# chaning the data type of the column "Happiness Rank"
df_hap['Happiness Rank'] = df_hap['Happiness Rank'].astype('str')

# %%
df_hap['Happiness Rank'].dtype
# Out:
# dtype('O')

# %%
df_hap.dtypes
# Out:
# Country                                        object
# Region                                         object
# Happiness Score                               float64
# Logged GDP per capita                         float64
# Healthy life expectancy                       float64
# Explained by: Log GDP per capita              float64
# Explained by: Social support                  float64
# Explained by: Healthy life expectancy         float64
# Explained by: Freedom to make life choices    float64
# Explained by: Generosity                      float64
# Explained by: Perceptions of corruption       float64
# Year                                           object
# Happiness Rank                                 object
# dtype: object

# %%
df_hap.describe()
# Out:
#        Happiness Score  Logged GDP per capita  Healthy life expectancy  \
# count      1297.000000            1099.000000              1119.000000
# mean          5.473737               9.330243                63.867401
# std           1.106996               1.182890                 7.397826
# min           1.859000               5.527000                38.718510
# 25%           4.635000               8.478003                59.000000
# 50%           5.488000               9.506083                65.482254
# 75%           6.269000              10.314471                69.223616
# max           7.842000              11.758369                76.953000
#
#        Explained by: Log GDP per capita  Explained by: Social support  \
# count                       1297.000000                   1297.000000
# mean                           1.022425                      1.056566
# std                            0.443272                      0.325512
# ...

# %% [markdown]
# ## Missing values

# %%
# finding missing values
df_hap.isnull().sum()
# Out:
# Country                                         0
# Region                                          0
# Happiness Score                                 0
# Logged GDP per capita                         198
# Healthy life expectancy                       178
# Explained by: Log GDP per capita                0
# Explained by: Social support                    0
# Explained by: Healthy life expectancy           0
# Explained by: Freedom to make life choices      0
# Explained by: Generosity                        0
# Explained by: Perceptions of corruption         0
# Year                                            0
# Happiness Rank                                  0
# dtype: int64

# %%
# Create a new dataframe
df_nan = df_hap[df_hap['Healthy life expectancy'].isnull() == True]

# %%
df_nan
# Out:
#                   Country                        Region  Happiness Score  \
# 190                 Qatar  Middle East and North Africa            6.375
# 194              Suriname   Latin America and Caribbean            6.269
# 197   Trinidad and Tobago   Latin America and Caribbean            6.168
# 201              Malaysia                Southeast Asia            6.005
# 215          North Cyprus                Western Europe            5.771
# ...                   ...                           ...              ...
# 1164             Tanzania            Sub-Saharan Africa            3.702
# 1165         Sierra Leone            Sub-Saharan Africa            3.574
# 1166             Zimbabwe            Sub-Saharan Africa            2.995
# 1167              Lebanon  Middle East and North Africa            2.955
# 1168          Afghanistan                    South Asia            2.404
#
#       Logged GDP per capita  Healthy life expectancy  \
# ...

# %% [markdown]
# ### Observation & Solution:
#
# As the analysis shows, we have a few missing values for the columns Healthy life expectancy and Logged GDP per capita. However, since we do not have any missing values in the same rows, such as for the Happiness Score or the Year, I will not do anything about the missing values, since they are not the focus of the analysis and the other data in the rows are more important.

# %%
# Sort df_happniss by country & year
df_hap.sort_values(['Country', 'Year'])
# Out:
#           Country              Region  Happiness Score  Logged GDP per capita  \
# 152   Afghanistan          South Asia           3.5750               7.556315
# 304   Afghanistan          South Asia           3.3600               7.497288
# 442   Afghanistan          South Asia           3.7940               7.497288
# 591   Afghanistan          South Asia           3.6320               7.460144
# 747   Afghanistan          South Asia           3.2030               7.494588
# ...           ...                 ...              ...                    ...
# 739      Zimbabwe  Sub-Saharan Africa           3.6630               7.553395
# 899      Zimbabwe  Sub-Saharan Africa           3.2992               7.865712
# 1049     Zimbabwe  Sub-Saharan Africa           3.1450               7.943000
# 1166     Zimbabwe  Sub-Saharan Africa           2.9950                    NaN
# 1293     Zimbabwe  Sub-Saharan Africa           3.2040               7.641000
#
# ...

# %%
# creating a subset 
df_hap_sorted = df_hap.sort_values(['Country', 'Year'])

# %% [markdown]
# ## Checking for Duplicates

# %%
# looking for duplicates
df_hap_sorted_dups = df_hap_sorted[df_hap_sorted.duplicated()]

# %%
# View df_ords_dups
df_hap_sorted_dups
# Out:
# Empty DataFrame
# Columns: [Country, Region, Happiness Score, Logged GDP per capita, Healthy life expectancy, Explained by: Log GDP per capita, Explained by: Social support, Explained by: Healthy life expectancy, Explained by: Freedom to make life choices, Explained by: Generosity, Explained by: Perceptions of corruption, Year, Happiness Rank]
# Index: []

# %%
df_hap_sorted.shape
# Out:
# (1297, 13)

# %% [markdown]
# ### Observation:
#
# no dups!

# %%
df_hap_sorted.describe()
# Out:
#        Happiness Score  Logged GDP per capita  Healthy life expectancy  \
# count      1297.000000            1099.000000              1119.000000
# mean          5.473737               9.330243                63.867401
# std           1.106996               1.182890                 7.397826
# min           1.859000               5.527000                38.718510
# 25%           4.635000               8.478003                59.000000
# 50%           5.488000               9.506083                65.482254
# 75%           6.269000              10.314471                69.223616
# max           7.842000              11.758369                76.953000
#
#        Explained by: Log GDP per capita  Explained by: Social support  \
# count                       1297.000000                   1297.000000
# mean                           1.022425                      1.056566
# std                            0.443272                      0.325512
# ...

# %% [markdown]
# ### Saving as a new dataset

# %%
# exporting Happiness report data
df_hap_sorted.to_csv(os.path.join(path,'Happiness_data_final.csv'))
